# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

A  = np.random.standard_normal((100, 2))
A += np.array((-1, -1))     # 분포 중심은 <-1, -1>

B  = np.random.standard_normal((100, 2))
B += np.array((1, 1))       # 분포 중심은 <1, 1>

plt.scatter(A[:,0], A[:,1], color='.25')
plt.scatter(B[:,0], B[:,1], color='.75')
plt.show()

# %%
# %more ./data/iris.data

# %%
# ?np.loadtxt

# %%
import numpy as np
import matplotlib.pyplot as plt

data_file = './data/iris.data'

label_set = (
    b'Iris-setosa',
    b'Iris-versicolor',
    b'Iris-virginica',
)

def read_label(label):
    return label_set.index(label)

data = np.loadtxt(data_file,
                  delimiter = ',',
                  converters = {4:read_label})

data
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 0. ],
#        [4.9, 3. , 1.4, 0.2, 0. ],
#        [4.7, 3.2, 1.3, 0.2, 0. ],
#        [4.6, 3.1, 1.5, 0.2, 0. ],
#        [5. , 3.6, 1.4, 0.2, 0. ],
#        [5.4, 3.9, 1.7, 0.4, 0. ],
#        [4.6, 3.4, 1.4, 0.3, 0. ],
#        [5. , 3.4, 1.5, 0.2, 0. ],
#        [4.4, 2.9, 1.4, 0.2, 0. ],
#        [4.9, 3.1, 1.5, 0.1, 0. ],
#        [5.4, 3.7, 1.5, 0.2, 0. ],
#        [4.8, 3.4, 1.6, 0.2, 0. ],
#        [4.8, 3. , 1.4, 0.1, 0. ],
#        [4.3, 3. , 1.1, 0.1, 0. ],
#        [5.8, 4. , 1.2, 0.2, 0. ],
#        [5.7, 4.4, 1.5, 0.4, 0. ],
#        [5.4, 3.9, 1.3, 0.4, 0. ],
#        [5.1, 3.5, 1.4, 0.3, 0. ],
#        [5.7, 3.8, 1.7, 0.3, 0. ],
#        [5.1, 3.8, 1.5, 0.3, 0. ],
#        [5.4, 3.4, 1.7, 0.2, 0. ],
#        [5.1, 3.7, 1.5, 0.4, 0. ],
#        [4.6, 3.6, 1. , 0.2, 0. ],
#        [5.1, 3.3, 1.7, 0.5, 0. ],
#        [4.8, 3.4, 1.9, 0.2, 0. ],
#        [5. , 3. , 1.6, 0.2, 0. ],
#        [5. , 3.4, 1.6, 0.4, 0. ],
#        [5.2, 3.5, 1.5, 0.2, 0. ],
#        [5.2, 3.4, 1.4, 0.2, 0. ],
#        [4.7, 3.2, 1.6, 0.2, 0. ],
#        [4.8, 3.1, 1.6, 0.2, 0. ],
#        [5.4, 3.4, 1.5, 0.4, 0. ],
#        [5.2, 4.1, 1.5, 0.1, 0. ],
#        [5.5, 4.2, 1.4, 0.2, 0. ],
#        [4.9, 3.1, 1.5, 0.1, 0. ],
#        [5. , 3.2, 1.2, 0.2, 0. ],
#        [5.5, 3.5, 1.3, 0.2, 0. ],
#        [4.9, 3.1, 1.5, 0.1, 0. ],
#        [4.4, 3. , 1.3, 0.2, 0. ],
#        [5.1, 3.4, 1.5, 0.2, 0. ],
#        [5. , 3.5, 1.3, 0.3, 0. ],
#        [4.5, 2.3, 1.3, 0.3, 0. ],
#        [4.4, 3.2, 1.3, 0.2, 0. ],
#        [5. , 3.5, 1.6, 0.6, 0. ],
#        [5.1, 3.8, 1.9, 0.4, 0. ],
#        [4.8, 3. , 1.4, 0.3, 0. ],
#        [5.1, 3.8, 1.6, 0.2, 0. ],
#        [4.6, 3.2, 1.4, 0.2, 0. ],
#        [5.3, 3.7, 1.5, 0.2, 0. ],
#        [5. , 3.3, 1.4, 0.2, 0. ],
#        [7. , 3.2, 4.7, 1.4, 1. ],
#        [6.4, 3.2, 4.5, 1.5, 1. ],
#        [6.9, 3.1, 4.9, 1.5, 1. ],
#        [5.5, 2.3, 4. , 1.3, 1. ],
#        [6.5, 2.8, 4.6, 1.5, 1. ],
#        [5.7, 2.8, 4.5, 1.3, 1. ],
#        [6.3, 3.3, 4.7, 1.6, 1. ],
#        [4.9, 2.4, 3.3, 1. , 1. ],
#        [6.6, 2.9, 4.6, 1.3, 1. ],
#        [5.2, 2.7, 3.9, 1.4, 1. ],
#        [5. , 2. , 3.5, 1. , 1. ],
#        [5.9, 3. , 4.2, 1.5, 1. ],
#        [6. , 2.2, 4. , 1. , 1. ],
#        [6.1, 2.9, 4.7, 1.4, 1. ],
#        [5.6, 2.9, 3.6, 1.3, 1. ],
#        [6.7, 3.1, 4.4, 1.4, 1. ],
#        [5.6, 3. , 4.5, 1.5, 1. ],
#        [5.8, 2.7, 4.1, 1. , 1. ],
#        [6.2, 2.2, 4.5, 1.5, 1. ],
#        [5.6, 2.5, 3.9, 1.1, 1. ],
#        [5.9, 3.2, 4.8, 1.8, 1. ],
#        [6.1, 2.8, 4. , 1.3, 1. ],
#        [6.3, 2.5, 4.9, 1.5, 1. ],
#        [6.1, 2.8, 4.7, 1.2, 1. ],
#        [6.4, 2.9, 4.3, 1.3, 1. ],
#        [6.6, 3. , 4.4, 1.4, 1. ],
#        [6.8, 2.8, 4.8, 1.4, 1. ],
#        [6.7, 3. , 5. , 1.7, 1. ],
#        [6. , 2.9, 4.5, 1.5, 1. ],
#        [5.7, 2.6, 3.5, 1. , 1. ],
#        [5.5, 2.4, 3.8, 1.1, 1. ],
#        [5.5, 2.4, 3.7, 1. , 1. ],
#        [5.8, 2.7, 3.9, 1.2, 1. ],
#        [6. , 2.7, 5.1, 1.6, 1. ],
#        [5.4, 3. , 4.5, 1.5, 1. ],
#        [6. , 3.4, 4.5, 1.6, 1. ],
#        [6.7, 3.1, 4.7, 1.5, 1. ],
#        [6.3, 2.3, 4.4, 1.3, 1. ],
#        [5.6, 3. , 4.1, 1.3, 1. ],
#        [5.5, 2.5, 4. , 1.3, 1. ],
#        [5.5, 2.6, 4.4, 1.2, 1. ],
#        [6.1, 3. , 4.6, 1.4, 1. ],
#        [5.8, 2.6, 4. , 1.2, 1. ],
#        [5. , 2.3, 3.3, 1. , 1. ],
#        [5.6, 2.7, 4.2, 1.3, 1. ],
#        [5.7, 3. , 4.2, 1.2, 1. ],
#        [5.7, 2.9, 4.2, 1.3, 1. ],
#        [6.2, 2.9, 4.3, 1.3, 1. ],
#        [5.1, 2.5, 3. , 1.1, 1. ],
#        [5.7, 2.8, 4.1, 1.3, 1. ],
#        [6.3, 3.3, 6. , 2.5, 2. ],
#        [5.8, 2.7, 5.1, 1.9, 2. ],
#        [7.1, 3. , 5.9, 2.1, 2. ],
#        [6.3, 2.9, 5.6, 1.8, 2. ],
#        [6.5, 3. , 5.8, 2.2, 2. ],
#        [7.6, 3. , 6.6, 2.1, 2. ],
#        [4.9, 2.5, 4.5, 1.7, 2. ],
#        [7.3, 2.9, 6.3, 1.8, 2. ],
#        [6.7, 2.5, 5.8, 1.8, 2. ],
#        [7.2, 3.6, 6.1, 2.5, 2. ],
#        [6.5, 3.2, 5.1, 2. , 2. ],
#        [6.4, 2.7, 5.3, 1.9, 2. ],
#        [6.8, 3. , 5.5, 2.1, 2. ],
#        [5.7, 2.5, 5. , 2. , 2. ],
#        [5.8, 2.8, 5.1, 2.4, 2. ],
#        [6.4, 3.2, 5.3, 2.3, 2. ],
#        [6.5, 3. , 5.5, 1.8, 2. ],
#        [7.7, 3.8, 6.7, 2.2, 2. ],
#        [7.7, 2.6, 6.9, 2.3, 2. ],
#        [6. , 2.2, 5. , 1.5, 2. ],
#        [6.9, 3.2, 5.7, 2.3, 2. ],
#        [5.6, 2.8, 4.9, 2. , 2. ],
#        [7.7, 2.8, 6.7, 2. , 2. ],
#        [6.3, 2.7, 4.9, 1.8, 2. ],
#        [6.7, 3.3, 5.7, 2.1, 2. ],
#        [7.2, 3.2, 6. , 1.8, 2. ],
#        [6.2, 2.8, 4.8, 1.8, 2. ],
#        [6.1, 3. , 4.9, 1.8, 2. ],
#        [6.4, 2.8, 5.6, 2.1, 2. ],
#        [7.2, 3. , 5.8, 1.6, 2. ],
#        [7.4, 2.8, 6.1, 1.9, 2. ],
#        [7.9, 3.8, 6.4, 2. , 2. ],
#        [6.4, 2.8, 5.6, 2.2, 2. ],
#        [6.3, 2.8, 5.1, 1.5, 2. ],
#        [6.1, 2.6, 5.6, 1.4, 2. ],
#        [7.7, 3. , 6.1, 2.3, 2. ],
#        [6.3, 3.4, 5.6, 2.4, 2. ],
#        [6.4, 3.1, 5.5, 1.8, 2. ],
#        [6. , 3. , 4.8, 1.8, 2. ],
#        [6.9, 3.1, 5.4, 2.1, 2. ],
#        [6.7, 3.1, 5.6, 2.4, 2. ],
#        [6.9, 3.1, 5.1, 2.3, 2. ],
#        [5.8, 2.7, 5.1, 1.9, 2. ],
#        [6.8, 3.2, 5.9, 2.3, 2. ],
#        [6.7, 3.3, 5.7, 2.5, 2. ],
#        [6.7, 3. , 5.2, 2.3, 2. ],
#        [6.3, 2.5, 5. , 1.9, 2. ],
#        [6.5, 3. , 5.2, 2. , 2. ],
#        [6.2, 3.4, 5.4, 2.3, 2. ],
#        [5.9, 3. , 5.1, 1.8, 2. ]])

# %%
import numpy as np
import matplotlib.pyplot as plt

data_file = './data/iris.data'

label_set = (
    b'Iris-setosa',
    b'Iris-versicolor',
    b'Iris-virginica',
)

def read_label(label):
    return label_set.index(label)

data = np.loadtxt(data_file,
                  delimiter = ',',
                  converters = {4:read_label})



color_set = ('00','.50','.75')
color_list = [color_set[int(label)] for label in data[:,4]]
color_set[int(label)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 19>()
#      13     return label_set.index(label)
#      15 data = np.loadtxt(data_file,
#      16                   delimiter = ',',
#      17                   converters = {4:read_label})
# ---> 19 read_label()
#
# TypeError: read_label() missing 1 required positional argument: 'label'

# %%
data
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 0. ],
#        [4.9, 3. , 1.4, 0.2, 0. ],
#        [4.7, 3.2, 1.3, 0.2, 0. ],
#        [4.6, 3.1, 1.5, 0.2, 0. ],
#        [5. , 3.6, 1.4, 0.2, 0. ],
#        [5.4, 3.9, 1.7, 0.4, 0. ],
#        [4.6, 3.4, 1.4, 0.3, 0. ],
#        [5. , 3.4, 1.5, 0.2, 0. ],
#        [4.4, 2.9, 1.4, 0.2, 0. ],
#        [4.9, 3.1, 1.5, 0.1, 0. ],
#        [5.4, 3.7, 1.5, 0.2, 0. ],
#        [4.8, 3.4, 1.6, 0.2, 0. ],
#        [4.8, 3. , 1.4, 0.1, 0. ],
#        [4.3, 3. , 1.1, 0.1, 0. ],
#        [5.8, 4. , 1.2, 0.2, 0. ],
#        [5.7, 4.4, 1.5, 0.4, 0. ],
#        [5.4, 3.9, 1.3, 0.4, 0. ],
#        [5.1, 3.5, 1.4, 0.3, 0. ],
#        [5.7, 3.8, 1.7, 0.3, 0. ],
#        [5.1, 3.8, 1.5, 0.3, 0. ],
#        [5.4, 3.4, 1.7, 0.2, 0. ],
#        [5.1, 3.7, 1.5, 0.4, 0. ],
#        [4.6, 3.6, 1. , 0.2, 0. ],
#        [5.1, 3.3, 1.7, 0.5, 0. ],
#        [4.8, 3.4, 1.9, 0.2, 0. ],
#        [5. , 3. , 1.6, 0.2, 0. ],
#        [5. , 3.4, 1.6, 0.4, 0. ],
#        [5.2, 3.5, 1.5, 0.2, 0. ],
#        [5.2, 3.4, 1.4, 0.2, 0. ],
#        [4.7, 3.2, 1.6, 0.2, 0. ],
#        [4.8, 3.1, 1.6, 0.2, 0. ],
#        [5.4, 3.4, 1.5, 0.4, 0. ],
#        [5.2, 4.1, 1.5, 0.1, 0. ],
#        [5.5, 4.2, 1.4, 0.2, 0. ],
#        [4.9, 3.1, 1.5, 0.1, 0. ],
#        [5. , 3.2, 1.2, 0.2, 0. ],
#        [5.5, 3.5, 1.3, 0.2, 0. ],
#        [4.9, 3.1, 1.5, 0.1, 0. ],
#        [4.4, 3. , 1.3, 0.2, 0. ],
#        [5.1, 3.4, 1.5, 0.2, 0. ],
#        [5. , 3.5, 1.3, 0.3, 0. ],
#        [4.5, 2.3, 1.3, 0.3, 0. ],
#        [4.4, 3.2, 1.3, 0.2, 0. ],
#        [5. , 3.5, 1.6, 0.6, 0. ],
#        [5.1, 3.8, 1.9, 0.4, 0. ],
#        [4.8, 3. , 1.4, 0.3, 0. ],
#        [5.1, 3.8, 1.6, 0.2, 0. ],
#        [4.6, 3.2, 1.4, 0.2, 0. ],
#        [5.3, 3.7, 1.5, 0.2, 0. ],
#        [5. , 3.3, 1.4, 0.2, 0. ],
#        [7. , 3.2, 4.7, 1.4, 1. ],
#        [6.4, 3.2, 4.5, 1.5, 1. ],
#        [6.9, 3.1, 4.9, 1.5, 1. ],
#        [5.5, 2.3, 4. , 1.3, 1. ],
#        [6.5, 2.8, 4.6, 1.5, 1. ],
#        [5.7, 2.8, 4.5, 1.3, 1. ],
#        [6.3, 3.3, 4.7, 1.6, 1. ],
#        [4.9, 2.4, 3.3, 1. , 1. ],
#        [6.6, 2.9, 4.6, 1.3, 1. ],
#        [5.2, 2.7, 3.9, 1.4, 1. ],
#        [5. , 2. , 3.5, 1. , 1. ],
#        [5.9, 3. , 4.2, 1.5, 1. ],
#        [6. , 2.2, 4. , 1. , 1. ],
#        [6.1, 2.9, 4.7, 1.4, 1. ],
#        [5.6, 2.9, 3.6, 1.3, 1. ],
#        [6.7, 3.1, 4.4, 1.4, 1. ],
#        [5.6, 3. , 4.5, 1.5, 1. ],
#        [5.8, 2.7, 4.1, 1. , 1. ],
#        [6.2, 2.2, 4.5, 1.5, 1. ],
#        [5.6, 2.5, 3.9, 1.1, 1. ],
#        [5.9, 3.2, 4.8, 1.8, 1. ],
#        [6.1, 2.8, 4. , 1.3, 1. ],
#        [6.3, 2.5, 4.9, 1.5, 1. ],
#        [6.1, 2.8, 4.7, 1.2, 1. ],
#        [6.4, 2.9, 4.3, 1.3, 1. ],
#        [6.6, 3. , 4.4, 1.4, 1. ],
#        [6.8, 2.8, 4.8, 1.4, 1. ],
#        [6.7, 3. , 5. , 1.7, 1. ],
#        [6. , 2.9, 4.5, 1.5, 1. ],
#        [5.7, 2.6, 3.5, 1. , 1. ],
#        [5.5, 2.4, 3.8, 1.1, 1. ],
#        [5.5, 2.4, 3.7, 1. , 1. ],
#        [5.8, 2.7, 3.9, 1.2, 1. ],
#        [6. , 2.7, 5.1, 1.6, 1. ],
#        [5.4, 3. , 4.5, 1.5, 1. ],
#        [6. , 3.4, 4.5, 1.6, 1. ],
#        [6.7, 3.1, 4.7, 1.5, 1. ],
#        [6.3, 2.3, 4.4, 1.3, 1. ],
#        [5.6, 3. , 4.1, 1.3, 1. ],
#        [5.5, 2.5, 4. , 1.3, 1. ],
#        [5.5, 2.6, 4.4, 1.2, 1. ],
#        [6.1, 3. , 4.6, 1.4, 1. ],
#        [5.8, 2.6, 4. , 1.2, 1. ],
#        [5. , 2.3, 3.3, 1. , 1. ],
#        [5.6, 2.7, 4.2, 1.3, 1. ],
#        [5.7, 3. , 4.2, 1.2, 1. ],
#        [5.7, 2.9, 4.2, 1.3, 1. ],
#        [6.2, 2.9, 4.3, 1.3, 1. ],
#        [5.1, 2.5, 3. , 1.1, 1. ],
#        [5.7, 2.8, 4.1, 1.3, 1. ],
#        [6.3, 3.3, 6. , 2.5, 2. ],
#        [5.8, 2.7, 5.1, 1.9, 2. ],
#        [7.1, 3. , 5.9, 2.1, 2. ],
#        [6.3, 2.9, 5.6, 1.8, 2. ],
#        [6.5, 3. , 5.8, 2.2, 2. ],
#        [7.6, 3. , 6.6, 2.1, 2. ],
#        [4.9, 2.5, 4.5, 1.7, 2. ],
#        [7.3, 2.9, 6.3, 1.8, 2. ],
#        [6.7, 2.5, 5.8, 1.8, 2. ],
#        [7.2, 3.6, 6.1, 2.5, 2. ],
#        [6.5, 3.2, 5.1, 2. , 2. ],
#        [6.4, 2.7, 5.3, 1.9, 2. ],
#        [6.8, 3. , 5.5, 2.1, 2. ],
#        [5.7, 2.5, 5. , 2. , 2. ],
#        [5.8, 2.8, 5.1, 2.4, 2. ],
#        [6.4, 3.2, 5.3, 2.3, 2. ],
#        [6.5, 3. , 5.5, 1.8, 2. ],
#        [7.7, 3.8, 6.7, 2.2, 2. ],
#        [7.7, 2.6, 6.9, 2.3, 2. ],
#        [6. , 2.2, 5. , 1.5, 2. ],
#        [6.9, 3.2, 5.7, 2.3, 2. ],
#        [5.6, 2.8, 4.9, 2. , 2. ],
#        [7.7, 2.8, 6.7, 2. , 2. ],
#        [6.3, 2.7, 4.9, 1.8, 2. ],
#        [6.7, 3.3, 5.7, 2.1, 2. ],
#        [7.2, 3.2, 6. , 1.8, 2. ],
#        [6.2, 2.8, 4.8, 1.8, 2. ],
#        [6.1, 3. , 4.9, 1.8, 2. ],
#        [6.4, 2.8, 5.6, 2.1, 2. ],
#        [7.2, 3. , 5.8, 1.6, 2. ],
#        [7.4, 2.8, 6.1, 1.9, 2. ],
#        [7.9, 3.8, 6.4, 2. , 2. ],
#        [6.4, 2.8, 5.6, 2.2, 2. ],
#        [6.3, 2.8, 5.1, 1.5, 2. ],
#        [6.1, 2.6, 5.6, 1.4, 2. ],
#        [7.7, 3. , 6.1, 2.3, 2. ],
#        [6.3, 3.4, 5.6, 2.4, 2. ],
#        [6.4, 3.1, 5.5, 1.8, 2. ],
#        [6. , 3. , 4.8, 1.8, 2. ],
#        [6.9, 3.1, 5.4, 2.1, 2. ],
#        [6.7, 3.1, 5.6, 2.4, 2. ],
#        [6.9, 3.1, 5.1, 2.3, 2. ],
#        [5.8, 2.7, 5.1, 1.9, 2. ],
#        [6.8, 3.2, 5.9, 2.3, 2. ],
#        [6.7, 3.3, 5.7, 2.5, 2. ],
#        [6.7, 3. , 5.2, 2.3, 2. ],
#        [6.3, 2.5, 5. , 1.9, 2. ],
#        [6.5, 3. , 5.2, 2. , 2. ],
#        [6.2, 3.4, 5.4, 2.3, 2. ],
#        [5.9, 3. , 5.1, 1.8, 2. ]])

# %%
sorted(set(color_list))
# Out:
# ['.00', '.50', '.75']

# %%
plt.scatter(data[:,0],data[:,1], color = color_list)
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal length (cm)')
plt.show()

# %%
plt.scatter(data[:,2], data[:,3], color=color_list)
plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data_file = './data/iris.data'
label_set = (
    b'Iris-setosa',
    b'Iris-versicolor',
    b'Iris-virginica',
)

def read_label(label):
    return label_set.index(label)

data = np.loadtxt(data_file,
                  delimiter = ',',
                  converters = {4: read_label})

color_set = ('.00', '.50', '.75')
color_list = [color_set[int(label)] for label in data[:,4]]

# plt.scatter(data[:,0], data[:,1], color=color_list)
# plt.show()

# %%
data[:10]
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 0. ],
#        [4.9, 3. , 1.4, 0.2, 0. ],
#        [4.7, 3.2, 1.3, 0.2, 0. ],
#        [4.6, 3.1, 1.5, 0.2, 0. ],
#        [5. , 3.6, 1.4, 0.2, 0. ],
#        [5.4, 3.9, 1.7, 0.4, 0. ],
#        [4.6, 3.4, 1.4, 0.3, 0. ],
#        [5. , 3.4, 1.5, 0.2, 0. ],
#        [4.4, 2.9, 1.4, 0.2, 0. ],
#        [4.9, 3.1, 1.5, 0.1, 0. ]])

# %%
len(data)
# Out:
# 150

# %%
sorted(set(color_list))
# Out:
# ['.00', '.50', '.75']

# %%
plt.scatter(data[:,0], data[:,1], color=color_list)
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
plt.show()

# %%
plt.scatter(data[:,2], data[:,3], color=color_list)
plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
plt.show()

# %%
plt.scatter(data[:,0], data[:,2], color=color_list, edgecolors='0.0')
plt.xlabel('sepal length (cm)')
plt.ylabel('petal length (cm)')
plt.show()

# %%
plt.scatter(data[:,0], data[:,2], color=color_list, edgecolors='0.0')
plt.xlabel('sepal width (cm)')
plt.ylabel('petal width (cm)')
plt.show()
