# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15 #글자크기
matplotlib.rcParams['axes.unicode_minus'] = False #한글 폰트 사용시, 마이너스 글자가 깨지는 현상을 해결

# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

# %matplotlib inline

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

plt.rcParams['figure.figsize'] = (10,6)

# %%
df = pd.read_csv('data/public_seoul_cctv_2020.csv',encoding='euc-kr')
df
# Out:
#     경찰서      개소      대수
# 0    중부     304     517
# 1    종로     214     480
# 2   남대문     159     202
# 3   서대문     376   1,131
# 4    혜화     215     481
# 5    용산     632   1,897
# 6    성북     453   1,276
# 7   동대문     486   1,396
# 8    마포     703     952
# 9   영등포     745   1,122
# 10   성동     497   1,252
# 11   동작     484   1,184
# 12   광진     637     642
# 13   서부     216     748
# 14   강북     696     840
# 15   금천     382   1,163
# 16   중랑     727     887
# 17   강남     596   1,612
# 18   관악   1,042   1,804
# 19   강서     576     870
# 20   강동     679     872
# 21   종암     295     767
# 22   구로     695   1,691
# 23   서초     344   1,079
# 24   양천     763   2,234
# 25   송파     675     779
# 26   노원   1,288   1,416
# 27   방배     236     830
# 28   은평     339   1,058
# 29   도봉     472     485
# 30   수서     677   1,856
# 31   총계  16,603  33,523

# %%
df.columns
# Out:
# Index(['경찰서', '개소', '대수'], dtype='object')

# %%
int(df.values[2,1].replace(',', ''))
# Out:
# 159

# %%
for n in np.arange(len(df)):
    df.values[n,1] = int(df.values[n,1].replace(',', ''))

# %%
for n in np.arange(len(df)):
    df.values[n,2] = int(df.values[n,2].replace(',', ''))

# %%
df
# Out:
#     경찰서     개소     대수
# 0    중부    304    517
# 1    종로    214    480
# 2   남대문    159    202
# 3   서대문    376   1131
# 4    혜화    215    481
# 5    용산    632   1897
# 6    성북    453   1276
# 7   동대문    486   1396
# 8    마포    703    952
# 9   영등포    745   1122
# 10   성동    497   1252
# 11   동작    484   1184
# 12   광진    637    642
# 13   서부    216    748
# 14   강북    696    840
# 15   금천    382   1163
# 16   중랑    727    887
# 17   강남    596   1612
# 18   관악   1042   1804
# 19   강서    576    870
# 20   강동    679    872
# 21   종암    295    767
# 22   구로    695   1691
# 23   서초    344   1079
# 24   양천    763   2234
# 25   송파    675    779
# 26   노원   1288   1416
# 27   방배    236    830
# 28   은평    339   1058
# 29   도봉    472    485
# 30   수서    677   1856
# 31   총계  16603  33523

# %%
df2 = df.drop(df.index[31])
df2
# Out:
#     경찰서    개소    대수
# 0    중부   304   517
# 1    종로   214   480
# 2   남대문   159   202
# 3   서대문   376  1131
# 4    혜화   215   481
# 5    용산   632  1897
# 6    성북   453  1276
# 7   동대문   486  1396
# 8    마포   703   952
# 9   영등포   745  1122
# 10   성동   497  1252
# 11   동작   484  1184
# 12   광진   637   642
# 13   서부   216   748
# 14   강북   696   840
# 15   금천   382  1163
# 16   중랑   727   887
# 17   강남   596  1612
# 18   관악  1042  1804
# 19   강서   576   870
# 20   강동   679   872
# 21   종암   295   767
# 22   구로   695  1691
# 23   서초   344  1079
# 24   양천   763  2234
# 25   송파   675   779
# 26   노원  1288  1416
# 27   방배   236   830
# 28   은평   339  1058
# 29   도봉   472   485
# 30   수서   677  1856

# %%
import seaborn as sns
sns.set()

# %%
df2_sort = df2.sort_values('대수',ascending=False)
df2_sort
# Out:
#        개소    대수
# 경찰서
# 양천    763  2234
# 용산    632  1897
# 수서    677  1856
# 관악   1042  1804
# 구로    695  1691
# 강남    596  1612
# 노원   1288  1416
# 동대문   486  1396
# 성북    453  1276
# 성동    497  1252
# 동작    484  1184
# 금천    382  1163
# 서대문   376  1131
# 영등포   745  1122
# 서초    344  1079
# 은평    339  1058
# 마포    703   952
# 중랑    727   887
# 강동    679   872
# 강서    576   870
# 강북    696   840
# 방배    236   830
# 송파    675   779
# 종암    295   767
# 서부    216   748
# 광진    637   642
# 중부    304   517
# 도봉    472   485
# 혜화    215   481
# 종로    214   480
# 남대문   159   202

# %%
df2_sort.index
# Out:
# Index(['양천', '용산', '수서', '관악', '구로', '강남', '노원', '동대문', '성북', '성동', '동작', '금천',
#        '서대문', '영등포', '서초', '은평', '마포', '중랑', '강동', '강서', '강북', '방배', '송파',
#        '종암', '서부', '광진', '중부', '도봉', '혜화', '종로', '남대문'],
#       dtype='object', name='경찰서')

# %%
df2.set_index('경찰서', inplace=True)
df2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [111], in <cell line: 1>()
# ----> 1 df2.set_index('경찰서', inplace=True)
#       2 df2.head()
#
# File C:\Python\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\Python\anaconda3\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
# ...

# %%
plt.rcParams["figure.figsize"] = [50,30]

sns.set_color_codes('pastel')
sns.barplot(x = df2_sort.index, y = df2_sort['대수'], color='b',label='CCTV 설치대수');

sns.set_color_codes('muted')
sns.barplot(x = df2_sort.index, y = df2_sort['개소'], color='b',label='파출소 개소');

plt.legend(ncol=2, loc=1,fontsize=40,frameon=True)
plt.title('\n 관할 경찰서별 파출소개소 및 CCTV설치수 현황 \n', fontsize=40)

plt.xticks(fontsize=40)
plt.yticks(fontsize=40)
plt.xlabel('경찰서', fontsize=40)
plt.ylabel('개소', fontsize=40)

plt.show()

# %%
plt.figure(figsize=(12,16))

sns.set_color_codes("pastel")
sns.barplot(x=df2_sort['대수'], y=df2_sort.index, color="b", label='CCTV 설치대수')

sns.set_color_codes("muted")
sns.barplot(x=df2_sort['개소'], y=df2_sort.index, color="b", label='파출소 개소')

plt.xticks(fontsize=20)
plt.legend(ncol=1, loc=4, fontsize=15, frameon=True)
plt.title('\n 관할 경찰서별 파출소개소 및 CCTV설치수 현황 \n', fontsize=20)

plt.show()

# %%
plt.rcParams["figure.figsize"] = [30,30]

A = df2['개소']
B = df2['대수']
C = df2['경찰서']

X = range(31)

plt.rcParams["figure.figsize"] = [30,10]

A.sort_values(ascending=False).plot(kind='bar',alpha=0.5);
B.sort_values(ascending=False).plot(kind='bar',alpha=0.5);

plt.xlabel('경찰서')
plt.ylabel('개소')
plt.legend(ncol=2, loc=1,frameon=True)
# plt.xticks(len(C)+0.3, C, fontsize=12)

plt.show()

# %%
df_cctv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [130], in <cell line: 1>()
# ----> 1 df_cctv
#
# NameError: name 'df_cctv' is not defined

# %%
plt.rcParams["figure.figsize"] = [15,15]

A = df2['개소']
B = df2['대수']
C = df2['경찰서']

plt.pie(df_cctv, 
        explode = explode,
        labels  = df_cctv.index,
        autopct = '%.1f%%', 
        shadow  = False, 
        startangle = 270
       )

B.plot(kind='pie', title='경찰서관할 CCTV(설치대수)')

plt.show()

# %%
plt.rcParams["figure.figsize"] = [15,15]

A = df2['개소']
B = df2['대수']
C = df2['경찰서']

A.plot(kind='pie', title='경찰서관할 파출소 (개소수)')

plt.show()

# %%
plt.figure(figsize=(20,20))

plt.subplot(211) 
plt.title('경찰서대수개소')

A = df2['개소']
B = df2['대수']
C = df2['경찰서']

X = range(31)

plt.rcParams["figure.figsize"] = [30,10]

A.sort_values(ascending=False).plot(kind='bar',alpha=0.5);
B.sort_values(ascending=False).plot(kind='bar',alpha=0.5);

plt.xlabel('경찰서')
plt.ylabel('개소')
plt.legend(loc=1)

plt.subplot(223) 
B.plot(kind='pie', title='경찰서관할 CCTV(설치대수)')

plt.subplot(224)
A.plot(kind='pie', title='경찰서관할 파출소 (개소수)')

plt.show()

# %%
df2['대수'].plot(kind='pie', fontsize=12, figsize=(10,10));
