# %%
# Pandas Basics
from IPython.display import Image 

from pandas import Series, DataFrame
import pandas as pd
import numpy as np

# %% [markdown]
# <font color = red><p style="font-weight:bold"> 상관관계와 공분산 </p></font>

# %%
# ?obj.dedscrbe()
# Out:
# Object `obj.dedscrbe()` not found.

# %%
obj = Series(['a', 'a', 'b', 'c'] * 4)
obj.describe()
# Out:
# count     16
# unique     3
# top        a
# freq       8
# dtype: object

# %%
help(describe)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 help(describe)
#
# NameError: name 'describe' is not defined

# %%
# import pandas.io.data as web
import pandas_datareader as web
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 # import pandas.io.data as web
# ----> 2 import pandas_datareader as web
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
# %pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# ...

# %%
# %pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import pandas.io.data as web
import pandas_datareader as web

# %%
all_data = {}
for ticker in ['AAPL', 'IBM', 'MSFT', 'GOOG']:
    all_data[ticker] = web.get_data_yahoo(ticker)

# %%
all_data2 = {}
for ticker in ['139130.KS', '175330.KS', '138930.KS', '006220.KS']: #대구,전북, 부산, 제주
    all_data2[ticker] = web.get_data_yahoo(ticker)

# %%
type(all_data['AAPL'])
# Out:
# pandas.core.frame.DataFrame

# %%
type(all_data['AAPL']['Adj Close'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# *주식이다

# %%
web.get_data_yahoo('{code}.KS'.format(code='139130'))
# Out:
#                High      Low     Open    Close    Volume    Adj Close
# Date
# 2017-05-31  11500.0  11300.0  11400.0  11500.0  674331.0  8930.117188
# 2017-06-01  11500.0  11250.0  11500.0  11300.0  575341.0  8774.811523
# 2017-06-02  11500.0  11350.0  11400.0  11450.0  591805.0  8891.291016
# 2017-06-05  11500.0  11350.0  11500.0  11450.0  347102.0  8891.291016
# 2017-06-07  11500.0  11350.0  11450.0  11500.0  506759.0  8930.117188
# ...             ...      ...      ...      ...       ...          ...
# 2022-05-24   8680.0   8550.0   8620.0   8560.0  525654.0  8560.000000
# 2022-05-25   8690.0   8570.0   8570.0   8600.0  395087.0  8600.000000
# 2022-05-26   8710.0   8630.0   8650.0   8660.0  402885.0  8660.000000
# 2022-05-27   8770.0   8690.0   8720.0   8750.0  307047.0  8750.000000
# 2022-05-30   8810.0   8750.0   8810.0   8770.0  209099.0  8770.000000
#
# [1225 rows x 6 columns]

# %%
all_data['AAPL'][0:10]
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2017-05-30  38.607498  38.332500  38.355000  38.417500   80507600.0  36.368549
# 2017-05-31  38.542500  38.095001  38.492500  38.189999   97804800.0  36.153183
# 2017-06-01  38.332500  38.055000  38.292500  38.294998   65616400.0  36.252579
# 2017-06-02  38.862499  38.222500  38.395000  38.862499  111082800.0  36.789803
# 2017-06-05  38.612499  38.365002  38.584999  38.482498  101326800.0  36.430069
# 2017-06-06  38.952499  38.445000  38.474998  38.612499  106499600.0  36.553143
# 2017-06-07  38.994999  38.619999  38.755001  38.842499   84278400.0  36.770874
# 2017-06-08  38.884998  38.599998  38.812500  38.747501   85003200.0  36.680946
# 2017-06-09  38.797501  36.505001  38.797501  37.244999  259530800.0  35.258575
# 2017-06-12  36.522499  35.627499  36.435001  36.355000  289229200.0  34.416039

# %%
all_data2.items()
# Out:
# dict_items([('139130.KS',                High      Low     Open    Close    Volume    Adj Close
# Date
# 2017-05-31  11500.0  11300.0  11400.0  11500.0  674331.0  8930.117188
# 2017-06-01  11500.0  11250.0  11500.0  11300.0  575341.0  8774.810547
# 2017-06-02  11500.0  11350.0  11400.0  11450.0  591805.0  8891.291016
# 2017-06-05  11500.0  11350.0  11500.0  11450.0  347102.0  8891.291016
# 2017-06-07  11500.0  11350.0  11450.0  11500.0  506759.0  8930.117188
# ...             ...      ...      ...      ...       ...          ...
# 2022-05-24   8680.0   8550.0   8620.0   8560.0  525654.0  8560.000000
# 2022-05-25   8690.0   8570.0   8570.0   8600.0  395087.0  8600.000000
# 2022-05-26   8710.0   8630.0   8650.0   8660.0  402885.0  8660.000000
# 2022-05-27   8770.0   8690.0   8720.0   8750.0  307047.0  8750.000000
# 2022-05-30   8810.0   8750.0   8810.0   8770.0  217470.0  8770.000000
#
# ...

# %%
all_data.items()
# Out:
# dict_items([('AAPL',                   High         Low        Open       Close       Volume  \
# Date
# 2017-05-30   38.607498   38.332500   38.355000   38.417500   80507600.0
# 2017-05-31   38.542500   38.095001   38.492500   38.189999   97804800.0
# 2017-06-01   38.332500   38.055000   38.292500   38.294998   65616400.0
# 2017-06-02   38.862499   38.222500   38.395000   38.862499  111082800.0
# 2017-06-05   38.612499   38.365002   38.584999   38.482498  101326800.0
# ...                ...         ...         ...         ...          ...
# 2022-05-23  143.259995  137.649994  137.789993  143.110001  117726300.0
# 2022-05-24  141.970001  137.330002  140.809998  140.360001  104132700.0
# 2022-05-25  141.789993  138.339996  138.429993  140.520004   92482700.0
# 2022-05-26  144.339996  137.139999  137.389999  143.779999   90601500.0
# 2022-05-27  149.679993  145.259995  145.389999  149.639999   90796900.0
#
#              Adj Close
# Date
# 2017-05-30   36.368549
# ...

# %%
price = DataFrame({tic: data['Adj Close']
                   for tic, data in all_data.items()})
price.head()
# Out:
#                  AAPL         IBM       MSFT        GOOG
# Date
# 2017-05-30  36.368549  114.588974  65.949806  975.880005
# 2017-05-31  36.153183  115.268723  65.415901  964.859985
# 2017-06-01  36.252579  115.298912  65.659447  966.950012
# 2017-06-02  36.789803  114.830681  67.214287  975.599976
# 2017-06-05  36.430069  115.102539  67.701340  983.679993

# %%
price2 = DataFrame({tic: data2['Adj Close']
                   for tic, data2 in all_data2.items()})
price2.tail(20)
# Out:
#             139130.KS  175330.KS  138930.KS  006220.KS
# Date
# 2022-04-29     8940.0     8950.0     7880.0     6350.0
# 2022-05-02     8850.0     8860.0     7890.0     6280.0
# 2022-05-03     8850.0     8790.0     7890.0     6270.0
# 2022-05-04     8870.0     8780.0     7890.0     6320.0
# 2022-05-06     9030.0     8700.0     7900.0     6320.0
# 2022-05-10     8860.0     8630.0     7770.0     6150.0
# 2022-05-11     8610.0     8530.0     7540.0     6100.0
# 2022-05-12     8500.0     8540.0     7530.0     6010.0
# 2022-05-13     8560.0     8600.0     7680.0     6070.0
# 2022-05-16     8560.0     8670.0     7700.0     6080.0
# 2022-05-17     8670.0     8870.0     7750.0     6060.0
# 2022-05-18     8740.0     8820.0     7720.0     6060.0
# 2022-05-19     8520.0     8710.0     7540.0     5950.0
# 2022-05-20     8560.0     8690.0     7620.0     6030.0
# 2022-05-23     8550.0     8770.0     7630.0     5970.0
# 2022-05-24     8560.0     8770.0     7710.0     5880.0
# ...

# %%
volume2 = DataFrame({tic: data2['Volume']
                    for tic, data2 in all_data2.items()})
volume2.tail(20)
# Out:
#             139130.KS   175330.KS  138930.KS  006220.KS
# Date
# 2022-04-29   764883.0    282623.0  1933562.0    93875.0
# 2022-05-02   586275.0    173993.0   771158.0    52535.0
# 2022-05-03   594070.0    219371.0   571551.0    27302.0
# 2022-05-04   432439.0    230442.0  1134566.0    47946.0
# 2022-05-06   548255.0    369611.0   951806.0    95517.0
# 2022-05-10   431232.0    288642.0  1339564.0   108383.0
# 2022-05-11   827483.0    351219.0  1895358.0    26867.0
# 2022-05-12   627348.0    246456.0  1249146.0    52851.0
# 2022-05-13   706593.0    210706.0  1030739.0    39946.0
# 2022-05-16   405730.0    190601.0   496974.0    15389.0
# 2022-05-17   384685.0    494813.0   651643.0    48859.0
# 2022-05-18   328390.0  27919385.0   692003.0    30785.0
# 2022-05-19   629038.0    279839.0  1077000.0    53840.0
# 2022-05-20   465168.0    471039.0   904664.0    28896.0
# 2022-05-23   242296.0    265315.0   479142.0    27375.0
# 2022-05-24   525654.0    371574.0   733742.0    69686.0
# ...

# %%
returns = price.pct_change()
returns.tail()
# Out:
#                 AAPL       IBM      MSFT      GOOG
# Date
# 2022-05-23  0.040119  0.020937  0.032032  0.021530
# 2022-05-24 -0.019216  0.020050 -0.003952 -0.051408
# 2022-05-25  0.001140  0.004410  0.011170 -0.000817
# 2022-05-26  0.023200  0.018603  0.012875  0.023210
# 2022-05-27  0.040757  0.017386  0.027604  0.041581

# %%
returns2 = price2.pct_change()
returns2.tail(30)
# Out:
#             139130.KS  175330.KS  138930.KS  006220.KS
# Date
# 2022-04-15  -0.003279   0.000000  -0.008772  -0.010989
# 2022-04-18  -0.004386   0.000000  -0.007585  -0.011111
# 2022-04-19   0.014317   0.002294   0.017834   0.004815
# 2022-04-20  -0.004343   0.009153  -0.003755   0.020767
# 2022-04-21   0.000000   0.003401   0.002513  -0.001565
# 2022-04-22   0.004362   0.018079   0.007519   0.018809
# 2022-04-25  -0.001086   0.000000  -0.004975  -0.004615
# 2022-04-26  -0.015217  -0.001110  -0.011250  -0.013910
# 2022-04-27  -0.022075  -0.016667  -0.026549  -0.034483
# 2022-04-28   0.005643   0.005650   0.014286   0.006494
# 2022-04-29   0.003367   0.005618   0.008963   0.024194
# 2022-05-02  -0.010067  -0.010056   0.001269  -0.011024
# 2022-05-03   0.000000  -0.007901   0.000000  -0.001592
# 2022-05-04   0.002260  -0.001138   0.000000   0.007974
# 2022-05-06   0.018038  -0.009112   0.001267   0.000000
# 2022-05-10  -0.018826  -0.008046  -0.016456  -0.026899
# ...

# %%
returns2 = volume2.pct_change()
returns2.tail(20)
# Out:
#             139130.KS  175330.KS  138930.KS  006220.KS
# Date
# 2022-04-29   0.112395  -0.010722   1.391436   0.280888
# 2022-05-02  -0.233510  -0.384364  -0.601172  -0.440373
# 2022-05-03   0.013296   0.260804  -0.258841  -0.480308
# 2022-05-04  -0.272074   0.050467   0.985065   0.756135
# 2022-05-06   0.267820   0.603922  -0.161084   0.992179
# 2022-05-10  -0.213446  -0.219065   0.407392   0.134699
# 2022-05-11   0.918881   0.216798   0.414907  -0.752111
# 2022-05-12  -0.241860  -0.298284  -0.340945   0.967134
# 2022-05-13   0.126317  -0.145056  -0.174845  -0.244177
# 2022-05-16  -0.425794  -0.095417  -0.517847  -0.614755
# 2022-05-17  -0.051869   1.596067   0.311222   2.174930
# 2022-05-18  -0.146341  55.424114   0.061936  -0.369922
# 2022-05-19   0.915521  -0.989977   0.556352   0.748904
# 2022-05-20  -0.260509   0.683250  -0.160015  -0.463299
# 2022-05-23  -0.479122  -0.436745  -0.470365  -0.052637
# 2022-05-24   1.169470   0.400501   0.531366   1.545607
# ...

# %%
returns2.corr()
# Out:
#            139130.KS  175330.KS  138930.KS  006220.KS
# 139130.KS   1.000000   0.057921   0.228492   0.093034
# 175330.KS   0.057921   1.000000   0.043267   0.023593
# 138930.KS   0.228492   0.043267   1.000000   0.054760
# 006220.KS   0.093034   0.023593   0.054760   1.000000

# %%
# ?price.pct_change

# %%
# ?head
# Out:
# Object `head` not found.

# %%
returns.MSFT.corr(returns.IBM)
# Out:
# 0.477269620899767

# %%
returns.AAPL.corr(returns.GOOG)
# Out:
# 0.6795174669589786

# %%
returns.MSFT.cov(returns.IBM)
# Out:
# 0.00014895041488129099

# %%
returns.corr()
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  1.000000  0.431414  0.754095  0.679517
# IBM   0.431414  1.000000  0.477270  0.450492
# MSFT  0.754095  0.477270  1.000000  0.784649
# GOOG  0.679517  0.450492  0.784649  1.000000

# %%
returns.cov()
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  0.000401  0.000147  0.000277  0.000247
# IBM   0.000147  0.000290  0.000149  0.000139
# MSFT  0.000277  0.000149  0.000336  0.000261
# GOOG  0.000247  0.000139  0.000261  0.000329

# %% [raw]
# * 공분산을 동일한 스케일로 판단할 수 있도록 한것이 상관계수이다.

# %%
returns.corrwith(returns.IBM)
# Out:
# AAPL    0.431414
# IBM     1.000000
# MSFT    0.477270
# GOOG    0.450492
# dtype: float64

# %%
returns.corrwith(volume)
# Out:
# AAPL   -0.083383
# IBM    -0.102587
# MSFT   -0.073838
# GOOG   -0.102146
# dtype: float64

# %% [markdown]
# *유일값,값 세기, 멤버십

# %%
obj = Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 obj = Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])
#
# NameError: name 'Series' is not defined

# %%
uniques = obj.unique()
uniques
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
obj.value_counts()
# Out:
# c    3
# a    3
# b    2
# d    1
# dtype: int64

# %%
pd.value_counts(obj.values, sort=False)
# Out:
# c    3
# a    3
# d    1
# b    2
# dtype: int64

# %%
pd.value_counts(obj.values, sort=True)
# Out:
# c    3
# a    3
# b    2
# d    1
# dtype: int64

# %%
mask = obj.isin(['b', 'c'])
mask
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
obj[mask]
# Out:
# 0    c
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
data = DataFrame({'Qu1': [1, 3, 4, 3, 4],
                  'Qu2': [2, 3, 1, 2, 3],
                  'Qu3': [1, 5, 2, 4, 4]})
data
# Out:
#    Qu1  Qu2  Qu3
# 0    1    2    1
# 1    3    3    5
# 2    4    1    2
# 3    3    2    4
# 4    4    3    4

# %%
# DataFrame.apply() 
result = data.apply(pd.value_counts).fillna(0)
result
# Out:
#    Qu1  Qu2  Qu3
# 1  1.0  1.0  1.0
# 2  0.0  2.0  1.0
# 3  2.0  2.0  0.0
# 4  2.0  0.0  2.0
# 5  0.0  0.0  1.0

# %%
# DataFrame.apply() 
result2 = reindex(data.apply(pd.value_counts),fill_value=0)
result2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 # DataFrame.apply()
# ----> 2 result2 = reindex(data.apply(pd.value_counts),fill_value=0)
#       3 result2
#
# NameError: name 'reindex' is not defined

# %%
# ?fillna
# Out:
# Object `fillna` not found.

# %%
# ?data.fillna
