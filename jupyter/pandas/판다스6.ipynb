# %%
# %pwd
# Out:
# 'C:\\Users\\student\\Anaconda_src\\S01_Pyton_Review'

# %%
# Pandas Basics
from IPython.display import Image 

from pandas import Series, DataFrame, MultiIndex
import pandas as pd
import numpy as np

# %%
data = Series(np.random.randn(10),
              index=[['a', 'a', 'a', 'b', 'b', 'b', 'c', 'c', 'd', 'd'],
                     [1, 2, 3, 1, 2, 3, 1, 2, 2, 3]])
data
# Out:
# a  1   -0.942322
#    2   -0.739852
#    3   -0.521633
# b  1   -1.122534
#    2    0.788289
#    3    2.341259
# c  1   -0.032361
#    2   -0.709215
# d  2    1.797965
#    3   -1.105076
# dtype: float64

# %%
data = Series(np.random.randn(10),index=[['a', 'a', 'a', 'b', 'b', 'b', 'c', 'c', 'd', 'd'],
                     [1, 2, 3, 1, 2, 3, 1, 2, 2, 3]])
data
# Out:
# a  1   -0.530182
#    2    0.495841
#    3    1.781527
# b  1    0.298200
#    2    1.048792
#    3   -1.159796
# c  1    0.321474
#    2    1.342268
# d  2   -0.185827
#    3    0.234663
# dtype: float64

# %%
data.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 2),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('d', 2),
#             ('d', 3)],
#            )

# %%
data['b']
# Out:
# 1   -1.122534
# 2    0.788289
# 3    2.341259
# dtype: float64

# %%
data['b':'c']
# Out:
# b  1   -1.122534
#    2    0.788289
#    3    2.341259
# c  1   -0.032361
#    2   -0.709215
# dtype: float64

# %%
data.loc[['b', 'd']]
# Out:
# b  1   -1.122534
#    2    0.788289
#    3    2.341259
# d  2    1.797965
#    3   -1.105076
# dtype: float64

# %%
data[:, 2]
# Out:
# a   -0.739852
# b    0.788289
# c   -0.709215
# d    1.797965
# dtype: float64

# %%
data
# Out:
# a  1   -0.530182
#    2    0.495841
#    3    1.781527
# b  1    0.298200
#    2    1.048792
#    3   -1.159796
# c  1    0.321474
#    2    1.342268
# d  2   -0.185827
#    3    0.234663
# dtype: float64

# %%
data[:, 1]
# Out:
# a   -0.530182
# b    0.298200
# c    0.321474
# dtype: float64

# %%
data['a', :]
# Out:
# 1   -0.530182
# 2    0.495841
# 3    1.781527
# dtype: float64

# %% [markdown]
# * 컬럼 값으로 올린다. -->  unstack()

# %%
data.unstack()
# Out:
#           1         2         3
# a -0.530182  0.495841  1.781527
# b  0.298200  1.048792 -1.159796
# c  0.321474  1.342268       NaN
# d       NaN -0.185827  0.234663

# %%
data.unstack().stack()
# Out:
# a  1   -0.530182
#    2    0.495841
#    3    1.781527
# b  1    0.298200
#    2    1.048792
#    3   -1.159796
# c  1    0.321474
#    2    1.342268
# d  2   -0.185827
#    3    0.234663
# dtype: float64

# %%
frame = DataFrame(np.arange(12).reshape((4, 3)),
                  index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]],
                  columns=[['Ohio', 'Ohio', 'Colorado'],
                           ['Green', 'Red', 'Green']])
frame
# Out:
#      Ohio     Colorado
#     Green Red    Green
# a 1     0   1        2
#   2     3   4        5
# b 1     6   7        8
#   2     9  10       11

# %%
frame.index.names   = ['key1',  'key2']
frame.columns.names = ['state', 'color']
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame['Ohio']
# Out:
# color      Green  Red
# key1 key2
# a    1         0    1
#      2         3    4
# b    1         6    7
#      2         9   10

# %%
frame['Colorado']
# Out:
# color      Green
# key1 key2
# a    1         2
#      2         5
# b    1         8
#      2        11

# %%
MultiIndex.from_arrays([['Ohio', 'Ohio', 'Colorado'], ['Green', 'Red', 'Green']],
                       names=['state', 'color'])
# Out:
# MultiIndex([(    'Ohio', 'Green'),
#             (    'Ohio',   'Red'),
#             ('Colorado', 'Green')],
#            names=['state', 'color'])

# %%
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.swaplevel('key1', 'key2')
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
# 2    a        3   4        5
# 1    b        6   7        8
# 2    b        9  10       11

# %%
frame.sort_index()
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.sort_index(axis=1)
# Out:
# state     Colorado  Ohio
# color        Green Green Red
# key1 key2
# a    1           2     0   1
#      2           5     3   4
# b    1           8     6   7
#      2          11     9  10

# %%
frame.sort_index(axis=1)
# Out:
# state     Colorado  Ohio
# color        Green Green Red
# key1 key2
# a    1           2     0   1
#      2           5     3   4
# b    1           8     6   7
#      2          11     9  10

# %%
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.sum(level='key2')
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_1296\2004046222.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   frame.sum(level='key2')
# state  Ohio     Colorado
# color Green Red    Green
# key2
# 1         6   8       10
# 2        12  14       16

# %%
frame.groupby(level=1).sum()
# Out:
# state  Ohio     Colorado
# color Green Red    Green
# key2
# 1         6   8       10
# 2        12  14       16

# %%
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.sum(level='color', axis=1)
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_1296\4133796543.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   frame.sum(level='color', axis=1)
# color      Green  Red
# key1 key2
# a    1         2    1
#      2         8    4
# b    1        14    7
#      2        20   10

# %%
frame.groupby(level='color', axis=1).sum()
# Out:
# color      Green  Red
# key1 key2
# a    1         2    1
#      2         8    4
# b    1        14    7
#      2        20   10

# %%
frame = DataFrame({'a': range(7), 
                   'b': range(7, 0, -1),
                   'c': ['one', 'one', 'one', 'two', 'two', 'two', 'two'],
                   'd': [0, 1, 2, 0, 1, 2, 3]})
frame
# Out:
#    a  b    c  d
# 0  0  7  one  0
# 1  1  6  one  1
# 2  2  5  one  2
# 3  3  4  two  0
# 4  4  3  two  1
# 5  5  2  two  2
# 6  6  1  two  3

# %%
frame2 = frame.set_index(['a','b'])
frame2
# Out:
#        c  d
# a b
# 0 7  one  0
# 1 6  one  1
# 2 5  one  2
# 3 4  two  0
# 4 3  two  1
# 5 2  two  2
# 6 1  two  3

# %%
frame.set_index(['a','b'],drop=False)
# Out:
#      a  b    c  d
# a b
# 0 7  0  7  one  0
# 1 6  1  6  one  1
# 2 5  2  5  one  2
# 3 4  3  4  two  0
# 4 3  4  3  two  1
# 5 2  5  2  two  2
# 6 1  6  1  two  3

# %%
frame2.reset_index()
# Out:
#    a  b    c  d
# 0  0  7  one  0
# 1  1  6  one  1
# 2  2  5  one  2
# 3  3  4  two  0
# 4  4  3  two  1
# 5  5  2  two  2
# 6  6  1  two  3

# %%
frame2
# Out:
#        c  d
# a b
# 0 7  one  0
# 1 6  one  1
# 2 5  one  2
# 3 4  two  0
# 4 3  two  1
# 5 2  two  2
# 6 1  two  3

# %%
frame2 = frame.set_index(['c', 'd'])
frame2
# Out:
#        a  b
# c   d
# one 0  0  7
#     1  1  6
#     2  2  5
# two 0  3  4
#     1  4  3
#     2  5  2
#     3  6  1

# %%
frame.set_index(['c', 'd'], drop=False)
# Out:
#        a  b    c  d
# c   d
# one 0  0  7  one  0
#     1  1  6  one  1
#     2  2  5  one  2
# two 0  3  4  two  0
#     1  4  3  two  1
#     2  5  2  two  2
#     3  6  1  two  3

# %%
frame2.reset_index()
# Out:
#      c  d  a  b
# 0  one  0  0  7
# 1  one  1  1  6
# 2  one  2  2  5
# 3  two  0  3  4
# 4  two  1  4  3
# 5  two  2  5  2
# 6  two  3  6  1

# %%
frame.sort_index(axis=1)
# Out:
#    a  b    c  d
# 0  0  7  one  0
# 1  1  6  one  1
# 2  2  5  one  2
# 3  3  4  two  0
# 4  4  3  two  1
# 5  5  2  two  2
# 6  6  1  two  3

# %%
frame.sort_index()
# Out:
#    a  b    c  d
# 0  0  7  one  0
# 1  1  6  one  1
# 2  2  5  one  2
# 3  3  4  two  0
# 4  4  3  two  1
# 5  5  2  two  2
# 6  6  1  two  3

# %%
frame.sort_index(axis=1, ascending=False)
# Out:
#    d    c  b  a
# 0  0  one  7  0
# 1  1  one  6  1
# 2  2  one  5  2
# 3  0  two  4  3
# 4  1  two  3  4
# 5  2  two  2  5
# 6  3  two  1  6

# %%
frame.sort_values(by=['b', 'd'])
# Out:
#    a  b    c  d
# 6  6  1  two  3
# 5  5  2  two  2
# 4  4  3  two  1
# 3  3  4  two  0
# 2  2  5  one  2
# 1  1  6  one  1
# 0  0  7  one  0
