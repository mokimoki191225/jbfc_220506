# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from IPython.display import Image

import re

# %%
# 웹드라이브로 크롬브라우즈 띄운다.
driver_path = "../driver/chromedriver.exe"
driver = webdriver.Chrome(executable_path=driver_path)
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_8020\3620293503.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=driver_path)

# %%
url_page = 'http://www.seleniumhq.org/projects/webdriver/'
url_page = 'https://www.tutorialspoint.com/selenium/'
driver.get(url_page)

# %%
# 페이지에서 Selenium - WebDriver 클릭 
driver.find_element_by_css_selector('#tocCollapse > div > ul:nth-child(3) > li:nth-child(8) > a').click()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_8020\3319716110.py:2: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector('#tocCollapse > div > ul:nth-child(3) > li:nth-child(8) > a').click()

# %%
capture_img = './images/selenium_webdriver.png'
driver.save_screenshot(capture_img)
Image(capture_img)
