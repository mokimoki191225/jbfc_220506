# %%
# %pwd
# Out:
# 'C:\\Users\\student\\Anaconda_src\\S01_Pyton_Review'

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# import seaborn as sns

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %matplotlib inline
plt.rcParams["figure.figsize"] = [12,6]

# %%
file_name = './data/public_incheon_cafe_2021.csv'

# %%
# csv파일 불러오기
# df = pd.read_csv(file_name, encoding='utf-8')  
# utf-8, euc-kr, cp949(마이크로소프트 제공)
df = pd.read_csv(file_name, encoding='euc-kr')
df.head()
# Out:
#    연번          사업장명                소재지지번주소                  소재지도로명주소  \
# 0   1  Cafe Arancia  인천광역시 중구 내동 212-22 1층  인천광역시 중구 우현로49번길 10-5 1층
# 1   2   디저트카페 아네모오네    인천광역시 중구 송학동3가 7-26     인천광역시 중구 신포로35번길 10-1
# 2   3         관동오리진     인천광역시 중구 관동1가 14-3       인천광역시 중구 신포로27번길 96
# 3   4          카페맑음      인천광역시 중구 신포동 48-3        인천광역시 중구 신포로 32-21
# 4   5            팟알       인천광역시 중구 관동1가 17     인천광역시 중구 신포로27번길 96-2
#
#       데이터기준일자
# 0  2021-08-05
# 1  2021-08-05
# 2  2021-08-05
# 3  2021-08-05
# 4  2021-08-05

# %%
col_addr1 = df['소재지지번주소']
col_addr1[0]
# Out:
# '인천광역시 중구 내동 212-22 1층'

# %%
col_addr2 = df['소재지도로명주소']
col_addr2[0]
# Out:
# '인천광역시 중구 우현로49번길 10-5 1층'

# %%
len(col_addr1), len(col_addr2)
# Out:
# (80, 80)

# %%
tmp = col_addr2[0].split() #공백으로 list만든다.
tmp[0:4]
# Out:
# ['인천광역시', '중구', '우현로49번길', '10-5']

# %%
# 주소 데이터 깔끔하게 다듬기
arr_address = list()
for idx in range(len(col_addr2)):
    tmp = col_addr2[idx].split()
    address = " ".join(tmp[0:4])
    arr_address.append(address)

# %%
arr_address[:5]
# Out:
# ['인천광역시 중구 우현로49번길 10-5',
#  '인천광역시 중구 신포로35번길 10-1',
#  '인천광역시 중구 신포로27번길 96',
#  '인천광역시 중구 신포로 32-21',
#  '인천광역시 중구 신포로27번길 96-2']

# %%
# %pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.2.0-py3-none-any.whl (118 kB)
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.52-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.52 geopy-2.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from geopy.geocoders import Nominatim

# %%
# 도로명주소 위도 경도 값으로 바꿔주기 
geo_local = Nominatim(user_agent='South Korea')

# %%
# 위도, 경도 반환하는 함수
def geocoding(address):
    '''
    geocoding함수 안에 주소를 넣어주면 그 주소에 맞는 위도, 경도를
    리스트로 만들어 [위도, 경도]로 반환
    '''
    geo = geo_local.geocode(address)
    
    print('{} : {}'.format(address, geo))  
    
    geo_loc = (geo.latitude, geo.longitude) if geo else (None,None)
    
    return geo_loc

# %%
geo.address # 미국식
# Out:
# '우현로49번길, 신포국제시장, 신포동, 중구, 인천, 22321, 대한민국'

# %%
address = arr_address[0]
address
# Out:
# '인천광역시 중구 우현로49번길 10-5'

# %%
geo = geo_local.geocode(address)
geo
# Out:
# Location(우현로49번길, 신포국제시장, 신포동, 중구, 인천, 22321, 대한민국, (37.4716422, 126.6273599, 0.0))

# %%
type(geo)
# Out:
# geopy.location.Location

# %%
dir(geo)[-10:]
# Out:
# ['_address',
#  '_point',
#  '_raw',
#  '_tuple',
#  'address',
#  'altitude',
#  'latitude',
#  'longitude',
#  'point',
#  'raw']

# %%
geo.address
# Out:
# '우현로49번길, 신포국제시장, 신포동, 중구, 인천, 22321, 대한민국'

# %%
geo.latitude
# Out:
# 37.4716422

# %%
geo.longitude
# Out:
# 126.6273599

# %%
geo.point
# Out:
# Point(37.4716422, 126.6273599, 0.0)

# %%
geo.raw
# Out:
# {'place_id': 206054857,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 472437323,
#  'boundingbox': ['37.4715467', '37.4717037', '126.6264296', '126.6285951'],
#  'lat': '37.4716422',
#  'lon': '126.6273599',
#  'display_name': '우현로49번길, 신포국제시장, 신포동, 중구, 인천, 22321, 대한민국',
#  'class': 'highway',
#  'type': 'service',
#  'importance': 0.295}

# %%
# from tqdm import tqdm_notebook
from tqdm.notebook import tqdm
import time

# %%
arr_lat = list()
arr_lon = list()

for idx in tqdm(df.index):
    #time.sleep(0.5) 
    #0.5초마다 계속 요청한다.
    # col_addr = df['소재지지번주소']
    col_addr = df['소재지도로명주소']
    # tmp = col_addr[idx].split()
    # address = " ".join(tmp[0:4])
    address = " ".join(col_addr[idx].split()[0:4])
    
    geo_lat, geo_lon =  geocoding(address)
    
    arr_lat.append(geo_lat)
    arr_lon.append(geo_lon)
# Out:
#   0%|          | 0/80 [00:00<?, ?it/s]
# 인천광역시 중구 우현로49번길 10-5 : 우현로49번길, 신포국제시장, 신포동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 신포로35번길 10-1 : 신포로35번길, 송학동2가, 관동1가, 중구, 인천, 22315, 대한민국
# 인천광역시 중구 신포로27번길 96 : 신포로27번길, 중앙동3가, 관동2가, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로 32-21 : 신포로, 중앙동4가, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로27번길 96-2 : 신포로27번길, 중앙동3가, 관동2가, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로35번길 64 : 신포로35번길, 송학동2가, 관동1가, 중구, 인천, 22315, 대한민국
# 인천광역시 중구 자유공원서로 21 : 자유공원서로, 인천차이나타운, 송월동, 중구, 인천, 22312, 대한민국
# 인천광역시 중구 차이나타운로44번길 16-24 : 차이나타운로44번길, 인천차이나타운, 북성동, 중구, 인천, 22312, 대한민국
# 인천광역시 중구 차이나타운로59번길 16 : 차이나타운로59번길, 선린동, 신포동, 중구, 인천, 22312, 대한민국
# 인천광역시 중구 신포로35번길 22-1 : 신포로35번길, 송학동2가, 관동1가, 중구, 인천, 22315, 대한민국
# 인천광역시 중구 제물량로166번길 1-6 : 제물량로166번길, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로35번길 17 : 신포로35번길, 송학동2가, 관동1가, 중구, 인천, 22315, 대한민국
# 인천광역시 중구 중앙동2가 23 : 중앙동2가, 신포동, 중구, 인천, 대한민국
# 인천광역시 중구 신포로39번길 23 : 신포로39번길, 송학동2가, 신포동, 중구, 인천, 22315, 대한민국
# 인천광역시 중구 신포로31번길 47 : 신포로31번길, 관동2가, 중구, 인천, 22315, 대한민국
# 인천광역시 중구 신포로23번길 23 : 신포로23번길, 중앙동2가, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 송학로 24-5 : 송학로, 송학동2가, 신포동, 중구, 인천, 22315, 대한민국
# 인천광역시 중구 신포로23번길 90 : 신포로23번길, 중앙동2가, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로46번길 35 : 신포로46번길, 내동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 신포로 27-1 : 신포로, 중앙동4가, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 제물량로218번길 3 : 제물량로218번길, 중앙동2가, 관동1가, 중구, 인천, 22315, 대한민국
# 인천광역시 중구 홍예문로 26-1 : 홍예문로, 동인천동, 중구, 인천, 22309, 대한민국
# 인천광역시 중구 신포로47번길 6 : 신포로47번길, 송학동2가, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 제물량로 137-1 : 제물량로, 해안동4가, 신포동, 중구, 인천, 22314, 대한민국
# 인천광역시 중구 개항로53번길 11 : 개항로53번길, 신포동 로데오거리, 내동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 제물량로166번길 14-1 : 제물량로166번길, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 개항로 49 : 개항로, 용동, 경동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 신포로27번길 97 : 신포로27번길, 중앙동3가, 관동2가, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로27번길 67 : 신포로27번길, 중앙동3가, 관동2가, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로23번길 80-1 : 신포로23번길, 중앙동2가, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로 35-1 : 신포로, 중앙동4가, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로23번길 80 : 신포로23번길, 중앙동2가, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로46번길 5 : 신포로46번길, 내동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 개항로 7-1 : 개항로, 용동, 경동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 개항로 29-2 : 개항로, 용동, 경동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 신포로27번길 93 : 신포로27번길, 중앙동3가, 관동2가, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로46번길 8-12 : 신포로46번길, 내동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 개항로 44-2 : 개항로, 용동, 경동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 개항로 31 : 개항로, 용동, 경동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 신포로 16-1 : 신포로, 중앙동4가, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로 27 : 신포로, 중앙동4가, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 개항로 29-1 : 개항로, 용동, 경동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 개항로 32 : 개항로, 용동, 경동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 신포로27번길 61 : 신포로27번길, 중앙동3가, 관동2가, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 인중로146번길 28 : 인중로146번길, 사동, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 개항로 28-2 : 개항로, 용동, 경동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 신포로27번길 87 : 신포로27번길, 중앙동3가, 관동2가, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 송학로 22 : 송학로, 동인천동, 중구, 인천, 22309, 대한민국
# 인천광역시 중구 우현로 67 : 우현로, 용동, 동인천동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 신포로39번길 23 : 신포로39번길, 송학동2가, 신포동, 중구, 인천, 22315, 대한민국
# 인천광역시 중구 제물량로206번길 33 : 제물량로206번길, 송학동2가, 관동2가, 중구, 인천, 22315, 대한민국
# 인천광역시 중구 인중로182번길 12 : 인중로182번길, 사동, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 우현로9번길 28 : 우현로9번길, 사동, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 우현로 49 : 우현로, 용동, 동인천동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 신포로35번길 8 : 신포로35번길, 송학동2가, 관동1가, 중구, 인천, 22315, 대한민국
# 인천광역시 중구 제물량로166번길 38 : 제물량로166번길, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 제물량로 210-4 : 제물량로, 해안동4가, 신포동, 중구, 인천, 22314, 대한민국
# 인천광역시 중구 신포로31번길 51-1 : 신포로31번길, 관동2가, 중구, 인천, 22315, 대한민국
# 인천광역시 중구 신포로27번길 83 : 신포로27번길, 중앙동3가, 관동2가, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 우현로35번길 23-1 : 우현로35번길, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 우현로39번길 12 : 우현로39번길, 신포국제시장, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 우현로35번길 8-1 : 우현로35번길, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 우현로35번길 14-2 : 우현로35번길, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로27번길 83 : 신포로27번길, 중앙동3가, 관동2가, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 제물량로232번안길 13 : 제물량로232번안길, 중앙동1가, 신포동, 중구, 인천, 22314, 대한민국
# 인천광역시 중구 신포로23번길 83 : 신포로23번길, 중앙동2가, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로39번길 6-4 : 신포로39번길, 송학동2가, 신포동, 중구, 인천, 22315, 대한민국
# 인천광역시 중구 신포로23번길 104 : 신포로23번길, 중앙동2가, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로 19-1 : 신포로, 중앙동4가, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 우현로35번길 11 : 우현로35번길, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로27번길 49 : 신포로27번길, 중앙동3가, 관동2가, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 제물량로166번길 17 : 제물량로166번길, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로23번길 52-1 : 신포로23번길, 중앙동2가, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 제물량로166번길 27 : 제물량로166번길, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 제물량로206번길 17 : 제물량로206번길, 송학동2가, 관동2가, 중구, 인천, 22315, 대한민국
# 인천광역시 중구 우현로39번길 12 : 우현로39번길, 신포국제시장, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 우현로45번길 25 : 우현로45번길, 신포국제시장, 신포동, 중구, 인천, 22322, 대한민국
# 인천광역시 중구 신포로31번길 51-1 : 신포로31번길, 관동2가, 중구, 인천, 22315, 대한민국
# 인천광역시 중구 개항로53번길 21 : 개항로53번길, 신포동 로데오거리, 내동, 중구, 인천, 22321, 대한민국
# 인천광역시 중구 우현로 12 : 우현로, 용동, 동인천동, 중구, 인천, 22321, 대한민국

# %%
geo_loc = list(zip(arr_lat,arr_lon))
geo_loc[:5]
# Out:
# [(37.4716422, 126.6273599),
#  (37.4733945, 126.6231442),
#  (37.4727937, 126.6225932),
#  (37.4709967, 126.6242367),
#  (37.4727937, 126.6225932)]

# %%
df.head()
# Out:
#    연번          사업장명                소재지지번주소                  소재지도로명주소  \
# 0   1  Cafe Arancia  인천광역시 중구 내동 212-22 1층  인천광역시 중구 우현로49번길 10-5 1층
# 1   2   디저트카페 아네모오네    인천광역시 중구 송학동3가 7-26     인천광역시 중구 신포로35번길 10-1
# 2   3         관동오리진     인천광역시 중구 관동1가 14-3       인천광역시 중구 신포로27번길 96
# 3   4          카페맑음      인천광역시 중구 신포동 48-3        인천광역시 중구 신포로 32-21
# 4   5            팟알       인천광역시 중구 관동1가 17     인천광역시 중구 신포로27번길 96-2
#
#       데이터기준일자
# 0  2021-08-05
# 1  2021-08-05
# 2  2021-08-05
# 3  2021-08-05
# 4  2021-08-05

# %%
file_name = './data/public_incheon_cafe_2021_with_geo.csv'

# %%
# Dataframe만들기
geo_df = pd.DataFrame({
    '카페이름' : df['사업장명'],
    '카페주소' : df['소재지도로명주소'],
    '위도' : arr_lat,
    '경도' : arr_lon
})

geo_df.head()
# Out:
#            카페이름                      카페주소         위도          경도
# 0  Cafe Arancia  인천광역시 중구 우현로49번길 10-5 1층  37.471642  126.627360
# 1   디저트카페 아네모오네     인천광역시 중구 신포로35번길 10-1  37.473394  126.623144
# 2         관동오리진       인천광역시 중구 신포로27번길 96  37.472794  126.622593
# 3          카페맑음        인천광역시 중구 신포로 32-21  37.470997  126.624237
# 4            팟알     인천광역시 중구 신포로27번길 96-2  37.472794  126.622593

# %%
#df저장
geo_df.to_csv(file_name)

# %%
chk_geo_df = pd.read_csv(file_name)
chk_geo_df.head()
# Out:
#    Unnamed: 0          카페이름                      카페주소         위도          경도
# 0           0  Cafe Arancia  인천광역시 중구 우현로49번길 10-5 1층  37.471642  126.627360
# 1           1   디저트카페 아네모오네     인천광역시 중구 신포로35번길 10-1  37.473394  126.623144
# 2           2         관동오리진       인천광역시 중구 신포로27번길 96  37.472794  126.622593
# 3           3          카페맑음        인천광역시 중구 신포로 32-21  37.470997  126.624237
# 4           4            팟알     인천광역시 중구 신포로27번길 96-2  37.472794  126.622593

# %%
chk_geo_df.columns
# Out:
# Index(['Unnamed: 0', '카페이름', '카페주소', '위도', '경도'], dtype='object')

# %%
del chk_geo_df[chk_geo_df.columns[0]]

# %%
chk_geo_df.tail()
# Out:
#       카페이름                   카페주소         위도          경도
# 75    낭만카페    인천광역시 중구 우현로39번길 12  37.470894  126.625950
# 76   또바기커피    인천광역시 중구 우현로45번길 25  37.471257  126.627222
# 77  카페와비사비  인천광역시 중구 신포로31번길 51-1  37.472425  126.624138
# 78   카페파구스    인천광역시 중구 개항로53번길 21  37.472645  126.628267
# 79   이삭커피숍        인천광역시 중구 우현로 12  37.472768  126.630054

# %% [markdown]
# * 그려보자

# %%
import json
import folium
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
len(chk_geo_df)
# Out:
# 80

# %%
chk_geo_df['위도'][0]
# Out:
# 37.4716422

# %%
map_1 = folium.Map(location=[chk_geo_df['위도'][0], chk_geo_df['경도'][0]], zoom_start=15, tiles='Stamen Terrain')

for idx in range(len(chk_geo_df)):
    folium.Marker([chk_geo_df['위도'][idx], chk_geo_df['경도'][idx]], popup=chk_geo_df['카페이름'][idx]
                  ,tiles = 'Stamen Terrain').add_to(map_1)
    map_1
# map.choropleth(geo_data=geo_str,
#               data = guDat,
#               columns=['gu', 'counts'],
#               fill_color='YlGnBu', #PuRd, YlGnBu
#               key_on='feature.id')

map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_451b68559b56043f357192f3182899c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_451b68559b56043f357192f3182899c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_451b68559b56043f357192f3182899c4 = L.map(
#                 &quot;map_451b68559b56043f357192f3182899c4&quot;,
#                 {
#                     center: [37.4716422, 126.6273599],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6bd207e91fb08f0ab678524f5b1bde4 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_451b68559b56043f357192f3182899c4);
#
#
#             var marker_aade7e9aeec22489ed2651f9de45f7cf = L.marker(
#                 [37.4716422, 126.6273599],
#                 {&quot;tiles&quot;: &quot;Stamen Terrain&quot;}
#             ).addTo(map_451b68559b56043f357192f3182899c4);
#
#
#         var popup_860cccd8a09f2bf410b21108e0bb0793 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6969062827fa177c92fc48c1bc260298 = $(`&lt;div id=&quot;html_6969062827fa177c92fc48c1bc260298&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cafe Arancia&lt;/div&gt;`)[0];
#             popup_860cccd8a09f2bf410b21108e0bb0793.setContent(html_6969062827fa177c92fc48c1bc260298);
#
#
#         marker_aade7e9aeec22489ed2651f9de45f7cf.bindPopup(popup_860cccd8a09f2bf410b21108e0bb0793)
#         ;
#
#
#
#
#             var marker_be06f764404536935c8f9dc1f34eae7b = L.marker(
#                 [37.4733945, 126.6231442],
#                 {&quot;tiles&quot;: &quot;Stamen Terrain&quot;}
#             ).addTo(map_451b68559b56043f357192f3182899c4);
#
#
#         var popup_a4b4ed50a04413731fd6745cdebd2139 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c9624ee63319b46b26deb5d95ea65d9d = $(`&lt;div id=&quot;html_c9624ee63319b46b26deb5d95ea65d9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;디저트카페 아네모오네&lt;/div&gt;`)[0];
#             popup_a4b4ed50a04413731fd6745cdebd2139.setContent(html_c9624ee63319b46b26deb5d95ea65d9d);
#
#
#         marker_be06f764404536935c8f9dc1f34eae7b.bindPopup(popup_a4b4ed50a04413731fd6745cdebd2139)
#         ;
#
#
#
#
#             var marker_e08970dfdb84aedf4aa4a6df44962286 = L.marker(
#                 [37.4727937, 126.6225932],
#                 {&quot;tiles&quot;: &quot;Stamen Terrain&quot;}
#             ).addTo(map_451b68559b56043f357192f3182899c4);
#
#
#         var popup_9a9429b7b50ffe467e771962d000c779 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_881f41af1dc018cb8414558627eec52c = $(`&lt;div id=&quot;html_881f41af1dc018cb8414558627eec52c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;관동오리진&lt;/div&gt;`)[0];
#             popup_9a9429b7b50ffe467e771962d000c779.setContent(html_881f41af1dc018cb8414558627eec52c);
#
#
#         marker_e08970dfdb84aedf4aa4a6df44962286.bindPopup(popup_9a9429b7b50ffe467e771962d000c779)
#         ;
#
#
#
#
#             var marker_31f18ddae04d49f33981e737245f9b4a = L.marker(
#                 [37.4709967, 126.6242367],
#                 {&quot;tiles&quot;: &quot;Stamen Terrain&quot;}
#             ).addTo(map_451b68559b56043f357192f3182899c4);
#
#
#         var popup_e9f46dda0c17d30048ef528170bf26af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a8671f0c0134269dfca17def875b28f1 = $(`&lt;div id=&quot;html_a8671f0c0134269dfca17def875b28f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;카페맑음&lt;/div&gt;`)[0];
#             popup_e9f46dda0c17d30048ef528170bf26af.setContent(html_a8671f0c0134269dfca17def875b28f1);
#
#
#         marker_31f18ddae04d49f33981e737245f9b4a.bindPopup(popup_e9f46dda0c17d30048ef528170bf26af)
#         ;
#
#
#
#
#             var marker_8fa76b2861edc2bded8d542e15ccb370 = L.marker(
#                 [37.4727937, 126.6225932],
#                 {&quot;tiles&quot;: &quot;Stamen Terrain&quot;}
#             ).addTo(map_451b68559b56043f357192f3182899c4);
#
#
#         var popup_cae53b74e310f929fc0c968dd0e121f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cfd5a7c5795cef545c6fac46952dab39 = $(`&lt;div id=&quot;html_cfd5a7c5795cef545c6fac46952dab39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팟알&lt;/div&gt;`)[0];
#             popup_cae53b74e310f929fc0c968dd0e121f1.setContent(html_cfd5a7c5795cef545c6fac46952dab39);
#
#
#         marker_8fa76b2861edc2bded8d542e15ccb370.bindPopup(popup_cae53b74e310f929fc0c968dd0e121f1)
#         ;

# %%
map_1 = folium.Map(location=[chk_geo_df['위도'][0], chk_geo_df['경도'][0]], zoom_start=15, tiles='Stamen Terrain')

for idx in range(len(chk_geo_df)):
    folium.Marker([chk_geo_df['위도'][idx], chk_geo_df['경도'][idx]], popup=chk_geo_df['카페이름'][idx]
                 ).add_to(map_1)
    folium.CircleMarker([chk_geo_df['위도'][idx], chk_geo_df['경도'][idx]], radius=5, popup=chk_geo_df['카페이름'][idx], color='#3186cc', fill_color='#3186cc' ).add_to(map_1)
    map_1

map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7907e7e73adaf3b8493b8ba0dff23d64 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7907e7e73adaf3b8493b8ba0dff23d64&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7907e7e73adaf3b8493b8ba0dff23d64 = L.map(
#                 &quot;map_7907e7e73adaf3b8493b8ba0dff23d64&quot;,
#                 {
#                     center: [37.4716422, 126.6273599],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77a8e68a77b14fe5bc70024738af9b38 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7907e7e73adaf3b8493b8ba0dff23d64);
#
#
#             var marker_c60b2a6328bbfdb30a36e583d5ec9414 = L.marker(
#                 [37.4716422, 126.6273599],
#                 {}
#             ).addTo(map_7907e7e73adaf3b8493b8ba0dff23d64);
#
#
#         var popup_276f6e41b539257eab37efaa92bc0be0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f3723b5d22d5a62c76c9ddfd5c614ac0 = $(`&lt;div id=&quot;html_f3723b5d22d5a62c76c9ddfd5c614ac0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cafe Arancia&lt;/div&gt;`)[0];
#             popup_276f6e41b539257eab37efaa92bc0be0.setContent(html_f3723b5d22d5a62c76c9ddfd5c614ac0);
#
#
#         marker_c60b2a6328bbfdb30a36e583d5ec9414.bindPopup(popup_276f6e41b539257eab37efaa92bc0be0)
#         ;
#
#
#
#
#             var circle_marker_2345b5be7e1a5b004e105c7647eef00d = L.circleMarker(
#                 [37.4716422, 126.6273599],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7907e7e73adaf3b8493b8ba0dff23d64);
#
#
#         var popup_85cec2709c709c9b6aa35b28859e0237 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b5ed7432993e30466c203ee676f8d772 = $(`&lt;div id=&quot;html_b5ed7432993e30466c203ee676f8d772&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cafe Arancia&lt;/div&gt;`)[0];
#             popup_85cec2709c709c9b6aa35b28859e0237.setContent(html_b5ed7432993e30466c203ee676f8d772);
#
#
#         circle_marker_2345b5be7e1a5b004e105c7647eef00d.bindPopup(popup_85cec2709c709c9b6aa35b28859e0237)
#         ;
#
#
#
#
#             var marker_7b25d5ff6a8029155a0606ac95e441d4 = L.marker(
#                 [37.4733945, 126.6231442],
#                 {}
#             ).addTo(map_7907e7e73adaf3b8493b8ba0dff23d64);
#
#
#         var popup_95dd27092be4be440cfa0ec485456d1e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_13cfb23e4a506236f5ed98982b1a0b74 = $(`&lt;div id=&quot;html_13cfb23e4a506236f5ed98982b1a0b74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;디저트카페 아네모오네&lt;/div&gt;`)[0];
#             popup_95dd27092be4be440cfa0ec485456d1e.setContent(html_13cfb23e4a506236f5ed98982b1a0b74);
#
#
#         marker_7b25d5ff6a8029155a0606ac95e441d4.bindPopup(popup_95dd27092be4be440cfa0ec485456d1e)
#         ;
#
#
#
#
#             var circle_marker_db2695d4f265dd678a215a49873748e0 = L.circleMarker(
#                 [37.4733945, 126.6231442],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7907e7e73adaf3b8493b8ba0dff23d64);
#
#
#         var popup_75fb84d674b8ed6fab8067d06cd6d7e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_129912d56af7af0b7f2648cb1807884c = $(`&lt;div id=&quot;html_129912d56af7af0b7f2648cb1807884c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;디저트카페 아네모오네&lt;/div&gt;`)[0];
#             popup_75fb84d674b8ed6fab8067d06cd6d7e8.setContent(html_129912d56af7af0b7f2648cb1807884c);
#
#
#         circle_marker_db2695d4f265dd678a215a49873748e0.bindPopup(popup_75fb84d674b8ed6fab8067d06cd6d7e8)
#         ;
