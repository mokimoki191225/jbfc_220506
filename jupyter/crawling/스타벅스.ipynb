# %%
# 스타벅스와 맥도날드의 상관관계를 본다. 개점일에 따른 증가와 감소를 파악한다.
# 셀레니움은 생략

# 0. URL에서 셀레니움으로 클릭하고 해당 서울까지 -> 전체

# %%
# 0. URL에서 셀레니움으로 클릭하고 해당 서울까지 -> 전체

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from IPython.display import Image
from urllib.request import urlopen

import pandas as pd
import time
import re

# %%
# 웹드라이브로 크롬브라우즈 띄운다.
driver_path = "../driver/chromedriver.exe"
driver = webdriver.Chrome(executable_path=driver_path)
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_10156\3620293503.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=driver_path)

# %%
# url_page = 'https://www.starbucks.co.kr/store/store_map.do'
# driver.get(url_page)

# %%
# url = 'https://www.starbucks.co.kr/store/store_map.do' #셀레니움 생략 그냥 쳐버린다.
# html = urlopen(url)
# soup = BeautifulSoup(html, "lxml")
# soup.title
# Out:
# <title id="titleJoin">Starbucks Korea</title>

# %%
# 지역검색 클릭
css_selector = '#container > div > form > fieldset > div > section > article.find_store_cont > article > header.loca_search > h3 > a'
driver.find_element(by=By.CSS_SELECTOR, value=css_selector).click()

# %%
# 페이지 BeautifulSoup 객체로 가져온다
html = driver.page_source
soup = BeautifulSoup(html, "lxml")
# html
# Out:
# '<html lang="ko"><head>\n\t\t\n\n\n\n\n\n\n\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no">\n<meta property="og:type" content="website">\n<meta property="og:title" content="Starbucks">\n<meta property="og:url" content="https://www.starbucks.co.kr/">\n<meta property="og:image" content="https://image.istarbucks.co.kr/common/img/kakaotalk.png">\n<meta property="og:description" content="Starbucks">\n\n<title id="titleJoin">Starbucks Korea</title> <!-- 220117 수정 -->\n<link rel="shortcut icon" href="https://image.istarbucks.co.kr/common/img/common/favicon.ico?v=200828" type="image/ico"> <!-- 20200827 파비콘 교체 및 CDN 변수처리 -->\n<link href="/common/css/reset.css" rel="stylesheet">\n<link href="/common/css/style.css?v=210721" rel="stylesheet">\n<link href="/common/css/jquery.bxslider.css" rel="stylesheet">\n<link href="/common/css/idangerous.swiper.css" rel="stylesheet">\n<link href="/common/css/idangerous.swiper.scrollbar.css" rel="stylesheet">\n<link href="/common/css/jquery.mCustomScrollbar.css" rel="stylesheet">\n<link href="/common/css/jquery.scrollbar.css" rel="stylesheet">\n<link href="/common/css/jquery-ui.css" rel="stylesheet">\n<link href="/common/css/ezmark.css" rel="stylesheet">\n<link href="/common/css/style_dt.css?v=20191211" rel="stylesheet"> <!-- 20191211 수정 -->\n\n<!--[if lt IE 9]>\n\t<script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script>\n\t<link href="/common/css_ie/style.css" rel="stylesheet">\n\t<script>\n\t\tdocument.createElement(\'header\');\n\t\tdocument.createElement(\'nav\');\n\t\tdocument.createElement(\'section\');\n\t\tdocument.createElement(\'figure\');\n\t\tdocument.createElement(\'article\');\n\t\tdocument.createElement(\'aside\');\n\t\tdocument.createElement(\'footer\');\n\t</script>\n<![endif]-->\n\n<script src="https://connect.facebook.net/ko_KR/sdk.js?hash=3cc9d8f60ff3d7d54cf5401ffb60e2a4" async="" crossorigin="anonymous"></script><script id="facebook-jssdk" src="//connect.facebook.net/ko_KR/sdk.js"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script>\n  (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n  })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n  ga(\'create\', \'UA-66158138-1\', \'auto\');\n  ga(\'send\', \'pageview\');\n</script>\n\n\n\n\n\n<script type="text/javascript">\nvar eFrequencyYn = \'Y\';\nvar eFrequencySeq = \'172\';\nvar eFrequencyPlannerYn = \'Y\';\n</script>\n\n\t\t<link href="/common/css/style_main.css?r=1abii2" rel="stylesheet">\n\t\t<link href="/common/css/style_whatsnew.css?r=1abii2" rel="stylesheet">\n\t\t<link href="/common/css/style_find_road.css?v=210423" rel="stylesheet">\n\t\t<link href="/common/css/style_util.css?v=210316" rel="stylesheet">\n\t\t<link href="/common/css/skdslider.css?r=1abii2" rel="stylesheet">\n\t\t<link href="/common/css/ezmark.css?r=1abii2" rel="stylesheet">\n\t<style type="text/css" data-fbcssmodules="css:fb.css.base css:fb.css.dialog css:fb.css.iframewidget css:fb.css.customer_chat_plugin_iframe">.fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:"lucida grande", tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset>div{overflow:hidden}@keyframes fb_transfo ...

# %%
# 전국 다 가져오면서 서울만도 가져온다.

# 전국단위
star_all = soup.find('article','store_map_layer_cont') #tbody는 하나니까 find로 찾아줘야 find_all로 했을시 뒤의 오류가 없다.
star_all = star_all.find_all('ul') 
star_all = star_all[1].find_all('li')
# star_all = star_all.find('a')
# 전체 구명 가져오기
# star_area = star_all[7]
# .find('ul')
# star_area
# star_all = star_all.get_text()
len(star_all)
# 0 ~ 16까지 돈다
star_all = star_all[0].get_text()
# star_all = star_all.find_all('a')
# star_all
# len(star_all)
# Out:
# 17

# %%
# 한 지역의 점포 상세히

# 서울클릭
css_selector = '#container > div > form > fieldset > div > section > article.find_store_cont > article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(1) > a'
driver.find_element(by=By.CSS_SELECTOR, value=css_selector).click()

# %%
# 전체클릭
css_selector = '#mCSB_2_container > ul > li:nth-child(1) > a'
driver.find_element(by=By.CSS_SELECTOR, value=css_selector).click()

# %%
# 매장정보 class
# 전국단위
# star_store = soup.find_all('ul','quickSearchResultBoxSidoGugun')
# star_store = soup.find_all('li') 
star_store = soup.find_all('div','result_list scrollbar-inner mCustomScrollbar _mCS_3')
star_store
# star_all = star_all.find_all('ul') 
# star_all = star_all[1].find_all('li')
# Out:
# []
